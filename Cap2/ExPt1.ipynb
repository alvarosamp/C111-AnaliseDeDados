# %%
#Crie um programa que leia seu nome completo e mostre

#nome1 = str(input('Digite seu nome '))
nome = "Alvaro Careli"
#Meu nome com as letras maiusculas
print(nome.upper())
#Nome com a letra minuscula
print(nome.lower())
#Quantas letras tem meu nome
print(len(nome))
#Como seria se trocar meu nome para 'do Inatel'
print(" ".join(nome.split()[:-1] + ["Do Inatel"]))
# Out:
# ALVARO CARELI
# alvaro careli
# 13
# Alvaro Do Inatel

# %%
#2 Mostre a tabuada de um numero que o usuario escolher dentro de um intervalo especifico tambem escolhido por ele
numero = int(input('Entre com um numero :'))
intervalo = int(input('Entre com um intervalo :'))
aux =0
for tabuada in range(intervalo):
  print(f'{numero} x {aux} = {numero * aux}')
  aux += 1
  # The 'if aux == intervalo: break' is redundant here because range(intervalo) already controls the loop's end.
# Out:
# Entre com um numero :5
# Entre com um intervalo :6
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25

# %%
sexo = input("Entre com o sexo (M/F): ")

while sexo != "M" and sexo != "F":
    print("Digite algo válido!")
    sexo = input("Entre com o sexo (M/F): ")

if sexo == "M":
    print("Masculino")
else:
    print("Feminino")
